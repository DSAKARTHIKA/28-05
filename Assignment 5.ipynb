# %%
#1.Loading the data into python environment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'C:\Users\ADMIN\OneDrive\Desktop\New folder\titanic_dataset.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#2. Make ‘PassengerId’ as the index column

# %%
data.set_index('PassengerId',inplace=True)
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
#3. Check the basic details of the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
#There are 891 rows and 11 coloumns
   # Columns Age, Cabin and embarked  have some missing values

# %%
data.shape
# Out:
# (891, 11)

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#4. Fill in all the missing values present in all the columns in the dataset
#step 1:Finding missing values

# %%
data.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
#Filling missing values

# %%
data['Age']=data['Age'].fillna(data['Age'].mean())
data['Cabin']=data['Cabin'].fillna(value='not known')
data['Embarked'] = data['Embarked'].fillna(data['Embarked'].mode().iloc[0])

# %%
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
data.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
#5. Check and handle outliers in at least 3 columns in the datas

# %%
#Fare:

# %%
plt.boxplot(data['Fare'])
plt.title('Box plot of Fare')
plt.show()

# %%
q1 = np.percentile(data['Fare'], 25)
q2 = np.percentile(data['Fare'], 50)
q3 = np.percentile(data['Fare'], 75)

# %%
iqr=q3-q1

# %%
low_limit = q1 - 1.5*iqr
upr_limit = q3 + 1.5*iqr

# %%
low_limit
# Out:
# -26.724

# %%
upr_limit
# Out:
# 65.6344

# %%
outlier = []
for x in data['Fare']:
    if x> upr_limit or x<low_limit:
        outlier.append(x)

# %%
ind2 = data.loc[data["Fare"].isin(outlier)].index

# %%
data.shape
# Out:
# (785, 11)

# %%
ind2.shape
# Out:
# (6,)

# %%
data.drop(ind2[:6],inplace=True)

# %%
data.shape
# Out:
# (779, 11)

# %%
#SibSp:

# %%
plt.boxplot(data["SibSp"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d95ba53040>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d95ba53610>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d95ba42d30>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d95ba53bb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d95ba53e80>],
#  'means': []}

# %%
q1 = np.percentile(data['SibSp'], 25)
q2 = np.percentile(data['SibSp'], 50)
q3 = np.percentile(data['SibSp'], 75)

# %%
iqr=q3-q1

# %%
low_limit = q1 - 1.5*iqr
upr_limit = q3 + 1.5*iqr

# %%
low_limit
# Out:
# -1.5

# %%
upr_limit
# Out:
# 2.5

# %%
outlier = []
for x in data['SibSp']:
    if x> upr_limit or x<low_limit:
        outlier.append(x)

# %%
outlier
# Out:
# [3,
#  4,
#  3,
#  3,
#  4,
#  5,
#  3,
#  4,
#  5,
#  3,
#  3,
#  4,
#  8,
#  4,
#  4,
#  3,
#  8,
#  4,
#  8,
#  3,
#  4,
#  4,
#  4,
#  4,
#  8,
#  3,
#  3,
#  5,
#  3,
#  5,
#  3,
#  4,
#  4,
#  3,
#  3,
#  5,
#  4,
#  3,
#  4,
#  8,
#  4,
#  3,
#  4,
#  8,
#  4,
#  8]

# %%
ind = data.loc[data["SibSp"].isin(outlier)].index

# %%
ind.shape
# Out:
# (46,)

# %%
data.drop(ind[:46],inplace=True)

# %%
data.shape
# Out:
# (845, 11)

# %%
plt.boxplot(data['SibSp'])
plt.title('Box plot of SibSp')
plt.show()

# %%
#Age:

# %%
plt.boxplot(data['Age'])
plt.show()

# %%
q1 = np.percentile(data['Age'], 25)
q2 = np.percentile(data['Age'], 50)
q3 = np.percentile(data['Age'], 75)

# %%
print(q1,q2,q3)
# Out:
# 23.0 29.69911764705882 36.0

# %%
iqr=q3-q1

# %%
iqr
# Out:
# 13.0

# %%
low_limit = q1 - 1.5*iqr
upr_limit = q3 + 1.5*iqr

# %%
low_limit
# Out:
# 3.5

# %%
upr_limit
# Out:
# 55.5

# %%
outlier = []
for x in data['Age']:
    if x> upr_limit or x<low_limit:
        outlier.append(x)

# %%
outlier
# Out:
# [58.0,
#  66.0,
#  3.0,
#  65.0,
#  0.83,
#  59.0,
#  71.0,
#  70.5,
#  61.0,
#  1.0,
#  56.0,
#  1.0,
#  3.0,
#  58.0,
#  2.0,
#  59.0,
#  62.0,
#  58.0,
#  63.0,
#  65.0,
#  2.0,
#  0.92,
#  61.0,
#  2.0,
#  3.0,
#  60.0,
#  1.0,
#  3.0,
#  64.0,
#  65.0,
#  56.0,
#  0.75,
#  2.0,
#  63.0,
#  58.0,
#  71.0,
#  2.0,
#  64.0,
#  62.0,
#  62.0,
#  60.0,
#  61.0,
#  57.0,
#  80.0,
#  0.75,
#  56.0,
#  58.0,
#  70.0,
#  60.0,
#  60.0,
#  70.0,
#  0.67,
#  57.0,
#  1.0,
#  0.42,
#  1.0,
#  62.0,
#  0.83,
#  74.0,
#  56.0]

# %%
ind = []
for i in data['Age']:
    if i<low_limit or i>upr_limit:
        ind.append(i)

# %%
ind
# Out:
# [58.0,
#  66.0,
#  3.0,
#  65.0,
#  0.83,
#  59.0,
#  71.0,
#  70.5,
#  61.0,
#  1.0,
#  56.0,
#  1.0,
#  3.0,
#  58.0,
#  2.0,
#  59.0,
#  62.0,
#  58.0,
#  63.0,
#  65.0,
#  2.0,
#  0.92,
#  61.0,
#  2.0,
#  3.0,
#  60.0,
#  1.0,
#  3.0,
#  64.0,
#  65.0,
#  56.0,
#  0.75,
#  2.0,
#  63.0,
#  58.0,
#  71.0,
#  2.0,
#  64.0,
#  62.0,
#  62.0,
#  60.0,
#  61.0,
#  57.0,
#  80.0,
#  0.75,
#  56.0,
#  58.0,
#  70.0,
#  60.0,
#  60.0,
#  70.0,
#  0.67,
#  57.0,
#  1.0,
#  0.42,
#  1.0,
#  62.0,
#  0.83,
#  74.0,
#  56.0]

# %%
ind1 = data.loc[data["Age"].isin(ind)].index

# %%
ind1
# Out:
# Int64Index([ 12,  34,  44,  55,  79,  95,  97, 117, 171, 173, 175, 184, 194,
#             196, 206, 233, 253, 269, 276, 281, 298, 306, 327, 341, 349, 367,
#             382, 408, 439, 457, 468, 470, 480, 484, 488, 494, 531, 546, 556,
#             571, 588, 626, 627, 631, 645, 648, 660, 673, 685, 695, 746, 756,
#             773, 789, 804, 828, 830, 832, 852, 880],
#            dtype='int64', name='PassengerId')

# %%
data.shape
# Out:
# (845, 11)

# %%
ind1.shape
# Out:
# (60,)

# %%
data.drop(ind1[:60],inplace=True)

# %%
data.shape
# Out:
# (785, 11)

# %%
#5.6. Do min max scaling on the feature set (Take ‘Survived’ as target)

# %%
data = data.drop(['Name', 'Ticket','Cabin'], axis=1)

# %%
data
# Out:
#              Survived  Pclass     Sex        Age  SibSp  Parch     Fare  \
# PassengerId
# 1                   0       3    male  22.000000      1      0   7.2500
# 2                   1       1  female  38.000000      1      0  71.2833
# 3                   1       3  female  26.000000      0      0   7.9250
# 4                   1       1  female  35.000000      1      0  53.1000
# 5                   0       3    male  35.000000      0      0   8.0500
# ...               ...     ...     ...        ...    ...    ...      ...
# 887                 0       2    male  27.000000      0      0  13.0000
# 888                 1       1  female  19.000000      0      0  30.0000
# 889                 0       3  female  29.699118      1      2  23.4500
# 890                 1       1    male  26.000000      0      0  30.0000
# 891                 0       3    male  32.000000      0      0   7.7500
#
#             Embarked
# PassengerId
# 1                  S
# 2                  C
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Sex'] = le.fit_transform(data['Sex'])

# %%
data['Embarked'] = le.fit_transform(data['Embarked'])

# %%
data
# Out:
#              Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# PassengerId
# 1                   0       3    1  22.000000      1      0   7.2500         2
# 2                   1       1    0  38.000000      1      0  71.2833         0
# 3                   1       3    0  26.000000      0      0   7.9250         2
# 4                   1       1    0  35.000000      1      0  53.1000         2
# 5                   0       3    1  35.000000      0      0   8.0500         2
# ...               ...     ...  ...        ...    ...    ...      ...       ...
# 887                 0       2    1  27.000000      0      0  13.0000         2
# 888                 1       1    0  19.000000      0      0  30.0000         2
# 889                 0       3    0  29.699118      1      2  23.4500         2
# 890                 1       1    1  26.000000      0      0  30.0000         0
# 891                 0       3    1  32.000000      0      0   7.7500         1
#
# ...

# %%
num_cols = ["Pclass", "Age", "SibSp", "Parch", "Fare","Embarked","Sex"]

# %%
X = data[num_cols]
y = data["Survived"].reset_index()

# %%
y
# Out:
#      PassengerId  Survived
# 0              1         0
# 1              2         1
# 2              3         1
# 3              4         1
# 4              5         0
# ..           ...       ...
# 774          887         0
# 775          888         1
# 776          889         0
# 777          890         1
# 778          891         0
#
# [779 rows x 2 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

#fit and transform the numerical features
X_scaled = scaler.fit_transform(X)

#convert the scaled array to a dataframe
X_scaled = pd.DataFrame(X_scaled, columns=num_cols)

# %%
X_scaled
# Out:
#      Pclass       Age  SibSp     Parch      Fare  Embarked  Sex
# 0       1.0  0.349515    0.5  0.000000  0.014151       1.0  1.0
# 1       0.0  0.660194    0.5  0.000000  0.139136       0.0  0.0
# 2       1.0  0.427184    0.0  0.000000  0.015469       1.0  0.0
# 3       0.0  0.601942    0.5  0.000000  0.103644       1.0  0.0
# 4       1.0  0.601942    0.0  0.000000  0.015713       1.0  1.0
# ..      ...       ...    ...       ...       ...       ...  ...
# 774     0.5  0.446602    0.0  0.000000  0.025374       1.0  1.0
# 775     0.0  0.291262    0.0  0.000000  0.058556       1.0  0.0
# 776     1.0  0.499012    0.5  0.333333  0.045771       1.0  0.0
# 777     0.0  0.427184    0.0  0.000000  0.058556       0.0  1.0
# 778     1.0  0.543689    0.0  0.000000  0.015127       0.5  1.0
#
# [779 rows x 7 columns]

# %%
X_final = pd.concat([y,X_scaled], ignore_index=True, axis=1)

# %%
X_final.columns =["Passenger ID","Survived","Pclass", "Age", "SibSp", "Parch", "Fare","Embarked","Sex"]
X_final.set_index("Passenger ID", inplace = True)

# %%
X_final
# Out:
#               Survived  Pclass       Age  SibSp     Parch      Fare  Embarked  \
# Passenger ID
# 1                    0     1.0  0.349515    0.5  0.000000  0.014151       1.0
# 2                    1     0.0  0.660194    0.5  0.000000  0.139136       0.0
# 3                    1     1.0  0.427184    0.0  0.000000  0.015469       1.0
# 4                    1     0.0  0.601942    0.5  0.000000  0.103644       1.0
# 5                    0     1.0  0.601942    0.0  0.000000  0.015713       1.0
# ...                ...     ...       ...    ...       ...       ...       ...
# 887                  0     0.5  0.446602    0.0  0.000000  0.025374       1.0
# 888                  1     0.0  0.291262    0.0  0.000000  0.058556       1.0
# 889                  0     1.0  0.499012    0.5  0.333333  0.045771       1.0
# 890                  1     0.0  0.427184    0.0  0.000000  0.058556       0.0
# 891                  0     1.0  0.543689    0.0  0.000000  0.015127       0.5
#
#               Sex
# ...
